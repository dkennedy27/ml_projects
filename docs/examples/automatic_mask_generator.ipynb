# %% [markdown]
# # Automatically generating object masks with SAM
#
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeos/segment-geospatial/blob/main/docs/examples/automatic_mask_generator.ipynb)
# [![image](https://img.shields.io/badge/Open-Planetary%20Computer-black?style=flat&logo=microsoft)](https://pccompute.westeurope.cloudapp.azure.com/compute/hub/user-redirect/git-pull?repo=https://github.com/opengeos/segment-geospatial&urlpath=lab/tree/segment-geospatial/docs/examples/automatic_mask_generator.ipynb&branch=main)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/segment-geospatial/blob/main/docs/examples/automatic_mask_generator.ipynb)
#
# This notebook shows how to segment objects from an image using the Segment Anything Model (SAM) with a few lines of code.
#
# Make sure you use GPU runtime for this notebook. For Google Colab, go to `Runtime` -> `Change runtime type` and select `GPU` as the hardware accelerator.
#
# The notebook is adapted from [segment-anything/notebooks/automatic_mask_generator_example.ipynb](https://github.com/opengeos/segment-anything/blob/pypi/notebooks/automatic_mask_generator_example.ipynb), but I have made it much easier to save the segmentation results and visualize them.

# %% [markdown]
# ## Install dependencies
#
# Uncomment and run the following cell to install the required dependencies.

# %%
# %pip install segment-geospatial
# Out:
# Collecting segment-geospatial
#   Downloading segment_geospatial-0.10.2-py2.py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 1.8 MB/s eta 0:00:00
# Collecting segment-anything-py (from segment-geospatial)
#   Downloading segment_anything_py-1.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 5.3 MB/s eta 0:00:00
# Collecting segment-anything-hq (from segment-geospatial)
#   Downloading segment_anything_hq-0.3-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.8.0.76)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2.0.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (3.7.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (0.20.3)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (0.13.2)
# Collecting rasterio (from segment-geospatial)
#   Downloading rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.66.2)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.7.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2023.10.1)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (3.6.1)
# Collecting leafmap (from segment-geospatial)
#   Downloading leafmap-0.31.5-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 84.8 MB/s eta 0:00:00
# Collecting localtileserver (from segment-geospatial)
#   Downloading localtileserver-0.10.1-py3-none-any.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 89.3 MB/s eta 0:00:00
# Collecting timm (from segment-geospatial)
#   Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 98.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (4.12.3)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas->segment-geospatial) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas->segment-geospatial) (23.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas->segment-geospatial) (1.5.3)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->segment-geospatial) (2.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj->segment-geospatial) (2024.2.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (4.10.0)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.12.43)
# Requirement already satisfied: colour in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.1.5)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.9.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.14.0)
# Collecting geojson (from leafmap->segment-geospatial)
#   Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.18.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (7.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (1.25.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (5.15.0)
# Requirement already satisfied: pyshp in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (2.3.1)
# Collecting pystac-client (from leafmap->segment-geospatial)
#   Downloading pystac_client-0.7.6-py3-none-any.whl (33 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (7.1.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.10/dist-packages (from leafmap->segment-geospatial) (0.9.2)
# Collecting whiteboxgui (from leafmap->segment-geospatial)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from localtileserver->segment-geospatial) (8.1.7)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver->segment-geospatial) (2.2.5)
# Collecting Flask-Caching (from localtileserver->segment-geospatial)
#   Downloading Flask_Caching-2.1.0-py3-none-any.whl (28 kB)
# Collecting flask-cors (from localtileserver->segment-geospatial)
#   Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Collecting flask-restx>=0.5.0 (from localtileserver->segment-geospatial)
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 76.6 MB/s eta 0:00:00
# Collecting rio-tiler (from localtileserver->segment-geospatial)
#   Downloading rio_tiler-6.4.1-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.5/262.5 kB 28.0 MB/s eta 0:00:00
# Collecting rio-cogeo (from localtileserver->segment-geospatial)
#   Downloading rio_cogeo-5.2.0-py3-none-any.whl (20 kB)
# Collecting server-thread (from localtileserver->segment-geospatial)
#   Downloading server_thread-0.2.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.10/dist-packages (from localtileserver->segment-geospatial) (3.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (2.8.2)
# Collecting affine (from rasterio->segment-geospatial)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (23.2.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->segment-geospatial)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (67.7.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from segment-anything-hq->segment-geospatial) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.8 in /usr/local/lib/python3.10/dist-packages (from segment-anything-hq->segment-geospatial) (0.16.0+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->segment-geospatial) (0.4.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (2.1.2)
# Collecting aniso8601>=0.82 (from flask-restx>=0.5.0->localtileserver->segment-geospatial)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver->segment-geospatial) (4.19.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver->segment-geospatial) (2023.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver->segment-geospatial) (6.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->segment-anything-hq->segment-geospatial) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->segment-anything-hq->segment-geospatial) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->segment-anything-hq->segment-geospatial) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug->localtileserver->segment-geospatial) (2.1.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->segment-geospatial) (2.5)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from bqplot->leafmap->segment-geospatial) (5.7.1)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from bqplot->leafmap->segment-geospatial) (0.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap->segment-geospatial) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap->segment-geospatial) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap->segment-geospatial) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap->segment-geospatial) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap->segment-geospatial) (3.0.10)
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching->localtileserver->segment-geospatial)
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium->leafmap->segment-geospatial) (0.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->leafmap->segment-geospatial) (8.2.3)
# Collecting pystac[validation]>=1.8.2 (from pystac-client->leafmap->segment-geospatial)
#   Downloading pystac-1.9.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->segment-geospatial) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->segment-geospatial) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->segment-geospatial) (2.0.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Collecting morecantile<6.0,>=5.0 (from rio-cogeo->localtileserver->segment-geospatial)
#   Downloading morecantile-5.3.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.10/dist-packages (from rio-cogeo->localtileserver->segment-geospatial) (2.6.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (5.3.3)
# Collecting color-operations (from rio-tiler->localtileserver->segment-geospatial)
#   Downloading color_operations-0.1.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 kB 19.1 MB/s eta 0:00:00
# Collecting httpx (from rio-tiler->localtileserver->segment-geospatial)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (2.9.0)
# Collecting uvicorn (from server-thread->localtileserver->segment-geospatial)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: ipytree in /usr/local/lib/python3.10/dist-packages (from whiteboxgui->leafmap->segment-geospatial) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap->segment-geospatial)
#   Downloading whitebox-2.3.1-py2.py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial) (6.3.3)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (2.16.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver->segment-geospatial) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver->segment-geospatial) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver->segment-geospatial) (0.18.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (6.5.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (3.7.1)
# Collecting httpcore==1.* (from httpx->rio-tiler->localtileserver->segment-geospatial)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->rio-tiler->localtileserver->segment-geospatial)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->segment-anything-hq->segment-geospatial) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (5.7.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial) (0.2.13)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->rio-tiler->localtileserver->segment-geospatial) (1.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (4.9.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (2.19.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (21.2.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial) (2.21)
# Installing collected packages: aniso8601, whitebox, snuggs, jedi, h11, geojson, color-operations, cachelib, affine, uvicorn, rasterio, pystac, httpcore, server-thread, morecantile, httpx, flask-cors, Flask-Caching, timm, segment-anything-py, segment-anything-hq, rio-tiler, rio-cogeo, flask-restx, pystac-client, localtileserver, whiteboxgui, leafmap, segment-geospatial
# Successfully installed Flask-Caching-2.1.0 affine-2.4.0 aniso8601-9.0.1 cachelib-0.9.0 color-operations-0.1.1 flask-cors-4.0.0 flask-restx-1.3.0 geojson-3.1.0 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 jedi-0.19.1 leafmap-0.31.5 localtileserver-0.10.1 morecantile-5.3.0 pystac-1.9.0 pystac-client-0.7.6 rasterio-1.3.9 rio-cogeo-5.2.0 rio-tiler-6.4.1 segment-anything-hq-0.3 segment-anything-py-1.0 segment-geospatial-0.10.2 server-thread-0.2.0 snuggs-1.4.7 timm-0.9.16 uvicorn-0.27.1 whitebox-2.3.1 whiteboxgui-2.3.0

# %%
import os
import leafmap
from samgeo import SamGeo, show_image, download_file, overlay_images, tms_to_geotiff

# %% [markdown]
# ## Create an interactive map

# %%
m = leafmap.Map(center=[39.60307, -93.17881], zoom=17, height="800px")
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[39.60307, -93.17881], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', …

# %% [markdown]
# Pan and zoom the map to select the area of interest. Use the draw tools to draw a polygon or rectangle on the map

# %%
if m.user_roi_bounds() is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-122.2659, 37.8682, -122.2521, 37.8741]

# %% [markdown]
# ## Download a sample image

# %%
image = "satellite.tif"
tms_to_geotiff(output=image, bbox=bbox, zoom=17, source="Satellite", overwrite=True)
# Out:
# Downloaded image 0001/1353
# Downloaded image 0002/1353
# Downloaded image 0003/1353
# Downloaded image 0004/1353
# Downloaded image 0005/1353
# Downloaded image 0006/1353
# Downloaded image 0007/1353
# Downloaded image 0008/1353
# Downloaded image 0009/1353
# Downloaded image 0010/1353
# Downloaded image 0011/1353
# Downloaded image 0012/1353
# Downloaded image 0013/1353
# Downloaded image 0014/1353
# Downloaded image 0015/1353
# Downloaded image 0016/1353
# Downloaded image 0017/1353
# Downloaded image 0018/1353
# Downloaded image 0019/1353
# Downloaded image 0020/1353
# Downloaded image 0021/1353
# Downloaded image 0022/1353
# Downloaded image 0023/1353
# Downloaded image 0024/1353
# Downloaded image 0025/1353
# Downloaded image 0026/1353
# Downloaded image 0027/1353
# Downloaded image 0028/1353
# Downloaded image 0029/1353
# Downloaded image 0030/1353
# Downloaded image 0031/1353
# Downloaded image 0032/1353
# Downloaded image 0033/1353
# Downloaded image 0034/1353
# Downloaded image 0035/1353
# Downloaded image 0036/1353
# Downloaded image 0037/1353
# Downloaded image 0038/1353
# Downloaded image 0039/1353
# Downloaded image 0040/1353
# Downloaded image 0041/1353
# Downloaded image 0042/1353
# Downloaded image 0043/1353
# Downloaded image 0044/1353
# Downloaded image 0045/1353
# Downloaded image 0046/1353
# Downloaded image 0047/1353
# Downloaded image 0048/1353
# Downloaded image 0049/1353
# Downloaded image 0050/1353
# Downloaded image 0051/1353
# Downloaded image 0052/1353
# Downloaded image 0053/1353
# Downloaded image 0054/1353
# Downloaded image 0055/1353
# Downloaded image 0056/1353
# Downloaded image 0057/1353
# Downloaded image 0058/1353
# Downloaded image 0059/1353
# Downloaded image 0060/1353
# Downloaded image 0061/1353
# Downloaded image 0593/1353
# Downloaded image 0594/1353
# Downloaded image 0595/1353
# Downloaded image 0596/1353
# Downloaded image 0597/1353
# Downloaded image 0598/1353
# Downloaded image 0599/1353
# Downloaded image 0600/1353
# Downloaded image 0601/1353
# Downloaded image 0602/1353
# Downloaded image 0603/1353
# Downloaded image 0604/1353
# Downloaded image 0605/1353
# Downloaded image 0606/1353
# Downloaded image 0607/1353
# Downloaded image 0608/1353
# Downloaded image 0609/1353
# Downloaded image 0610/1353
# Downloaded image 0611/1353
# Downloaded image 0612/1353
# Downloaded image 0613/1353
# Downloaded image 0614/1353
# Downloaded image 0615/1353
# Downloaded image 0616/1353
# Downloaded image 0617/1353
# Downloaded image 0618/1353
# Downloaded image 0619/1353
# Downloaded image 0620/1353
# Downloaded image 0621/1353
# Downloaded image 0622/1353
# Downloaded image 0623/1353
# Downloaded image 0624/1353
# Downloaded image 0625/1353
# Downloaded image 0626/1353
# Downloaded image 0627/1353
# Downloaded image 0628/1353
# Downloaded image 0629/1353
# Downloaded image 0630/1353
# Downloaded image 0631/1353
# Downloaded image 0632/1353
# Downloaded image 0633/1353
# Downloaded image 0634/1353
# Downloaded image 0635/1353
# Downloaded image 0636/1353
# Downloaded image 0637/1353
# Downloaded image 0638/1353
# Downloaded image 0639/1353
# Downloaded image 0640/1353
# Downloaded image 0641/1353
# Downloaded image 0642/1353
# Downloaded image 0643/1353
# Downloaded image 0644/1353
# Downloaded image 0645/1353
# Downloaded image 0646/1353
# Downloaded image 0647/1353
# Downloaded image 0648/1353
# Downloaded image 0649/1353
# Downloaded image 0650/1353
# Downloaded image 0651/1353
# Downloaded image 0652/1353
# Downloaded image 0653/1353
# Downloaded image 0654/1353
# Downloaded image 0655/1353
# Downloaded image 0656/1353
# Downloaded image 0657/1353
# Downloaded image 0658/1353
# Downloaded image 0659/1353
# Downloaded image 0660/1353
# Downloaded image 0661/1353
# Downloaded image 0662/1353
# Downloaded image 0663/1353
# Downloaded image 0664/1353
# Downloaded image 0665/1353
# Downloaded image 0666/1353
# Downloaded image 0667/1353
# Downloaded image 0668/1353
# Downloaded image 0669/1353
# Downloaded image 0670/1353
# Downloaded image 0671/1353
# Downloaded image 0672/1353
# Downloaded image 0673/1353
# Downloaded image 0674/1353
# Downloaded image 0675/1353
# Downloaded image 0676/1353
# Downloaded image 0677/1353
# Downloaded image 0678/1353
# Downloaded image 0679/1353
# Downloaded image 0680/1353
# Downloaded image 0681/1353
# Downloaded image 0682/1353
# Downloaded image 0683/1353
# Downloaded image 0684/1353
# Downloaded image 0685/1353
# Downloaded image 0686/1353
# Downloaded image 0687/1353
# Downloaded image 0688/1353
# Downloaded image 0689/1353
# Downloaded image 0690/1353
# Downloaded image 0691/1353
# Downloaded image 0692/1353
# Downloaded image 0693/1353
# Downloaded image 0694/1353
# Downloaded image 0695/1353
# Downloaded image 0696/1353
# Downloaded image 0697/1353
# Downloaded image 0698/1353
# Downloaded image 0699/1353
# Downloaded image 0700/1353
# Downloaded image 0701/1353
# Downloaded image 0702/1353
# Downloaded image 0703/1353
# Downloaded image 0704/1353
# Downloaded image 0705/1353
# Downloaded image 0706/1353
# Downloaded image 0707/1353
# Downloaded image 0708/1353
# Downloaded image 0709/1353
# Downloaded image 0710/1353
# Downloaded image 0711/1353
# Downloaded image 0712/1353
# Downloaded image 0713/1353
# Downloaded image 0714/1353
# Downloaded image 0715/1353
# Downloaded image 0716/1353
# Downloaded image 0717/1353
# Downloaded image 0718/1353
# Downloaded image 0719/1353
# Downloaded image 0720/1353
# Downloaded image 0721/1353
# Downloaded image 0722/1353
# Downloaded image 0723/1353
# Downloaded image 0724/1353
# Downloaded image 0725/1353
# Downloaded image 0726/1353
# Downloaded image 0727/1353
# Downloaded image 0728/1353
# Downloaded image 0729/1353
# Downloaded image 0730/1353
# Downloaded image 0731/1353
# Downloaded image 0732/1353
# Downloaded image 0733/1353
# Downloaded image 0734/1353
# Downloaded image 0735/1353
# Downloaded image 0736/1353
# Downloaded image 0737/1353
# Downloaded image 0738/1353
# Downloaded image 0739/1353
# Downloaded image 0740/1353
# Downloaded image 0741/1353
# Downloaded image 0742/1353
# Downloaded image 0743/1353
# Downloaded image 0744/1353
# Downloaded image 0745/1353
# Downloaded image 0746/1353
# Downloaded image 0747/1353
# Downloaded image 0748/1353
# Downloaded image 0749/1353
# Downloaded image 0750/1353
# Downloaded image 0751/1353
# Downloaded image 0752/1353
# Downloaded image 0753/1353
# Downloaded image 0754/1353
# Downloaded image 0755/1353
# Downloaded image 0756/1353
# Downloaded image 0757/1353
# Downloaded image 0758/1353
# Downloaded image 0759/1353
# Downloaded image 0760/1353
# Downloaded image 0761/1353
# Downloaded image 0762/1353
# Downloaded image 0763/1353
# Downloaded image 0764/1353
# Downloaded image 0765/1353
# Downloaded image 0766/1353
# Downloaded image 0767/1353
# Downloaded image 0768/1353
# Downloaded image 0769/1353
# Downloaded image 0770/1353
# Downloaded image 0771/1353
# Downloaded image 0772/1353
# Downloaded image 0773/1353
# Downloaded image 0774/1353
# Downloaded image 0775/1353
# Downloaded image 0776/1353
# Downloaded image 0777/1353
# Downloaded image 0778/1353
# Downloaded image 0779/1353
# Downloaded image 0780/1353
# Downloaded image 0781/1353
# Downloaded image 0782/1353
# Downloaded image 0783/1353
# Downloaded image 0784/1353
# Downloaded image 0785/1353
# Downloaded image 0786/1353
# Downloaded image 0787/1353
# Downloaded image 0788/1353
# Downloaded image 0789/1353
# Downloaded image 0790/1353
# Downloaded image 0791/1353
# Downloaded image 0792/1353
# Downloaded image 0793/1353
# Downloaded image 0794/1353
# Downloaded image 0795/1353
# Downloaded image 0796/1353
# Downloaded image 0797/1353
# Downloaded image 0798/1353
# Downloaded image 0799/1353
# Downloaded image 0800/1353
# Downloaded image 0801/1353
# Downloaded image 0802/1353
# Downloaded image 0803/1353
# Downloaded image 0804/1353
# Downloaded image 0805/1353
# Downloaded image 0912/1353
# Downloaded image 0913/1353
# Downloaded image 0914/1353
# Downloaded image 0915/1353
# Downloaded image 0916/1353
# Downloaded image 0917/1353
# Downloaded image 0918/1353
# Downloaded image 0919/1353
# Downloaded image 0920/1353
# Downloaded image 0921/1353
# Downloaded image 0922/1353
# Downloaded image 0923/1353
# Downloaded image 0924/1353
# Downloaded image 0925/1353
# Downloaded image 0926/1353
# Downloaded image 0927/1353
# Downloaded image 0928/1353
# Downloaded image 0929/1353
# Downloaded image 0930/1353
# Downloaded image 0931/1353
# Downloaded image 0932/1353
# Downloaded image 0933/1353
# Downloaded image 0934/1353
# Downloaded image 0935/1353
# Downloaded image 0936/1353
# Downloaded image 0937/1353
# Downloaded image 0938/1353
# Downloaded image 0939/1353
# Downloaded image 0940/1353
# Downloaded image 0941/1353
# Downloaded image 0942/1353
# Downloaded image 0943/1353
# Downloaded image 0944/1353
# Downloaded image 0945/1353
# Downloaded image 0946/1353
# Downloaded image 0947/1353
# Downloaded image 0948/1353
# Downloaded image 0949/1353
# Downloaded image 0950/1353
# Downloaded image 0951/1353
# Downloaded image 0952/1353
# Downloaded image 0953/1353
# Downloaded image 0954/1353
# Downloaded image 0955/1353
# Downloaded image 0956/1353
# Downloaded image 0957/1353
# Downloaded image 0958/1353
# Downloaded image 0959/1353
# Downloaded image 0960/1353
# Downloaded image 0961/1353
# Downloaded image 0962/1353
# Downloaded image 0963/1353
# Downloaded image 0964/1353
# Downloaded image 0965/1353
# Downloaded image 0966/1353
# Downloaded image 0967/1353
# Downloaded image 0968/1353
# Downloaded image 0969/1353
# Downloaded image 0970/1353
# Downloaded image 0971/1353
# Downloaded image 0972/1353
# Downloaded image 0973/1353
# Downloaded image 0974/1353
# Downloaded image 0975/1353
# Downloaded image 0976/1353
# Downloaded image 0977/1353
# Downloaded image 0978/1353
# Downloaded image 0979/1353
# Downloaded image 0980/1353
# Downloaded image 0981/1353
# Downloaded image 0982/1353
# Downloaded image 0983/1353
# Downloaded image 0984/1353
# Downloaded image 0985/1353
# Downloaded image 0986/1353
# Downloaded image 0987/1353
# Downloaded image 0988/1353
# Downloaded image 0989/1353
# Downloaded image 0990/1353
# Downloaded image 0991/1353
# Downloaded image 0992/1353
# Downloaded image 0993/1353
# Downloaded image 0994/1353
# Downloaded image 0995/1353
# Downloaded image 0996/1353
# Downloaded image 0997/1353
# Downloaded image 0998/1353
# Downloaded image 0999/1353
# Downloaded image 1000/1353
# Downloaded image 1001/1353
# Downloaded image 1002/1353
# Downloaded image 1003/1353
# Downloaded image 1004/1353
# Downloaded image 1005/1353
# Downloaded image 1006/1353
# Downloaded image 1007/1353
# Downloaded image 1008/1353
# Downloaded image 1009/1353
# Downloaded image 1010/1353
# Downloaded image 1011/1353
# Downloaded image 1012/1353
# Downloaded image 1013/1353
# Downloaded image 1014/1353
# Downloaded image 1015/1353
# Downloaded image 1016/1353
# Downloaded image 1017/1353
# Downloaded image 1018/1353
# Downloaded image 1019/1353
# Downloaded image 1020/1353
# Downloaded image 1021/1353
# Downloaded image 1022/1353
# Downloaded image 1023/1353
# Downloaded image 1024/1353
# Downloaded image 1025/1353
# Downloaded image 1026/1353
# Downloaded image 1027/1353
# Downloaded image 1028/1353
# Downloaded image 1029/1353
# Downloaded image 1030/1353
# Downloaded image 1031/1353
# Downloaded image 1032/1353
# Downloaded image 1033/1353
# Downloaded image 1034/1353
# Downloaded image 1035/1353
# Downloaded image 1036/1353
# Downloaded image 1037/1353
# Downloaded image 1038/1353
# Downloaded image 1039/1353
# Downloaded image 1040/1353
# Downloaded image 1041/1353
# Downloaded image 1042/1353
# Downloaded image 1043/1353
# Downloaded image 1044/1353
# Downloaded image 1045/1353
# Downloaded image 1046/1353
# Downloaded image 1047/1353
# Downloaded image 1048/1353
# Downloaded image 1049/1353
# Downloaded image 1050/1353
# Downloaded image 1051/1353
# Downloaded image 1052/1353
# Downloaded image 1053/1353
# Downloaded image 1054/1353
# Downloaded image 1055/1353
# Downloaded image 1056/1353
# Downloaded image 1057/1353
# Downloaded image 1058/1353
# Downloaded image 1059/1353
# Downloaded image 1060/1353
# Downloaded image 1061/1353
# Downloaded image 1062/1353
# Downloaded image 1063/1353
# Downloaded image 1064/1353
# Downloaded image 1065/1353
# Downloaded image 1066/1353
# Downloaded image 1067/1353
# Downloaded image 1068/1353
# Downloaded image 1069/1353
# Downloaded image 1070/1353
# Downloaded image 1071/1353
# Downloaded image 1072/1353
# Downloaded image 1073/1353
# Downloaded image 1074/1353
# Downloaded image 1075/1353
# Downloaded image 1076/1353
# Downloaded image 1077/1353
# Downloaded image 1078/1353
# Downloaded image 1079/1353
# Downloaded image 1080/1353
# Downloaded image 1081/1353
# Downloaded image 1082/1353
# Downloaded image 1083/1353
# Downloaded image 1084/1353
# Downloaded image 1085/1353
# Downloaded image 1086/1353
# Downloaded image 1087/1353
# Downloaded image 1088/1353
# Downloaded image 1089/1353
# Downloaded image 1090/1353
# Downloaded image 1091/1353
# Downloaded image 1092/1353
# Downloaded image 1093/1353
# Downloaded image 1094/1353
# Downloaded image 1095/1353
# Downloaded image 1096/1353
# Downloaded image 1097/1353
# Downloaded image 1098/1353
# Downloaded image 1099/1353
# Downloaded image 1100/1353
# Downloaded image 1101/1353
# Downloaded image 1102/1353
# Downloaded image 1103/1353
# Downloaded image 1104/1353
# Downloaded image 1105/1353
# Downloaded image 1106/1353
# Downloaded image 1107/1353
# Downloaded image 1108/1353
# Downloaded image 1109/1353
# Downloaded image 1110/1353
# Downloaded image 1111/1353
# Downloaded image 1112/1353
# Downloaded image 1113/1353
# Downloaded image 1114/1353
# Downloaded image 1115/1353
# Downloaded image 1116/1353
# Downloaded image 1117/1353
# Downloaded image 1118/1353
# Downloaded image 1119/1353
# Downloaded image 1120/1353
# Downloaded image 1121/1353
# Downloaded image 1122/1353
# Downloaded image 1123/1353
# Downloaded image 1124/1353
# Downloaded image 1125/1353
# Downloaded image 1126/1353
# Downloaded image 1127/1353
# Downloaded image 1128/1353
# Downloaded image 1129/1353
# Downloaded image 1130/1353
# Downloaded image 1131/1353
# Downloaded image 1132/1353
# Downloaded image 1133/1353
# Downloaded image 1134/1353
# Downloaded image 1135/1353
# Downloaded image 1136/1353
# Downloaded image 1137/1353
# Downloaded image 1138/1353
# Downloaded image 1139/1353
# Downloaded image 1140/1353
# Downloaded image 1141/1353
# Downloaded image 1142/1353
# Downloaded image 1143/1353
# Downloaded image 1144/1353
# Downloaded image 1145/1353
# Downloaded image 1146/1353
# Downloaded image 1147/1353
# Downloaded image 1148/1353
# Downloaded image 1149/1353
# Downloaded image 1150/1353
# Downloaded image 1151/1353
# Downloaded image 1152/1353
# Downloaded image 1153/1353
# Downloaded image 1154/1353
# Downloaded image 1155/1353
# Downloaded image 1156/1353
# Downloaded image 1157/1353
# Downloaded image 1158/1353
# Downloaded image 1159/1353
# Downloaded image 1160/1353
# Downloaded image 1161/1353
# Downloaded image 1162/1353
# Downloaded image 1163/1353
# Downloaded image 1164/1353
# Downloaded image 1165/1353
# Downloaded image 1166/1353
# Downloaded image 1167/1353
# Downloaded image 1168/1353
# Downloaded image 1169/1353
# Downloaded image 1170/1353
# Downloaded image 1171/1353
# Downloaded image 1172/1353
# Downloaded image 1173/1353
# Downloaded image 1174/1353
# Downloaded image 1175/1353
# Downloaded image 1176/1353
# Downloaded image 1177/1353
# Downloaded image 1178/1353
# Downloaded image 1179/1353
# Downloaded image 1180/1353
# Downloaded image 1181/1353
# Downloaded image 1182/1353
# Downloaded image 1183/1353
# Downloaded image 1184/1353
# Downloaded image 1185/1353
# Downloaded image 1186/1353
# Downloaded image 1187/1353
# Downloaded image 1188/1353
# Downloaded image 1189/1353
# Downloaded image 1190/1353
# Downloaded image 1191/1353
# Downloaded image 1192/1353
# Downloaded image 1193/1353
# Downloaded image 1194/1353
# Downloaded image 1195/1353
# Downloaded image 1196/1353
# Downloaded image 1197/1353
# Downloaded image 1198/1353
# Downloaded image 1199/1353
# Downloaded image 1200/1353
# Downloaded image 1201/1353
# Downloaded image 1202/1353
# Downloaded image 1203/1353
# Downloaded image 1204/1353
# Downloaded image 1205/1353
# Downloaded image 1206/1353
# Downloaded image 1207/1353
# Downloaded image 1208/1353
# Downloaded image 1209/1353
# Downloaded image 1210/1353
# Downloaded image 1211/1353
# Downloaded image 1212/1353
# Downloaded image 1213/1353
# Downloaded image 1214/1353
# Downloaded image 1215/1353
# Downloaded image 1216/1353
# Downloaded image 1217/1353
# Downloaded image 1218/1353
# Downloaded image 1219/1353
# Downloaded image 1220/1353
# Downloaded image 1221/1353
# Downloaded image 1222/1353
# Downloaded image 1223/1353
# Downloaded image 1224/1353
# Downloaded image 1225/1353
# Downloaded image 1226/1353
# Downloaded image 1227/1353
# Downloaded image 1228/1353
# Downloaded image 1229/1353
# Downloaded image 1230/1353
# Downloaded image 1231/1353
# Downloaded image 1232/1353
# Downloaded image 1233/1353
# Downloaded image 1234/1353
# Downloaded image 1235/1353
# Downloaded image 1236/1353
# Downloaded image 1237/1353
# Downloaded image 1238/1353
# Downloaded image 1239/1353
# Downloaded image 1240/1353
# Downloaded image 1241/1353
# Downloaded image 1242/1353
# Downloaded image 1243/1353
# Downloaded image 1244/1353
# Downloaded image 1245/1353
# Downloaded image 1246/1353
# Downloaded image 1247/1353
# Downloaded image 1248/1353
# Downloaded image 1249/1353
# Downloaded image 1250/1353
# Downloaded image 1251/1353
# Downloaded image 1252/1353
# Downloaded image 1253/1353
# Downloaded image 1254/1353
# Downloaded image 1255/1353
# Downloaded image 1256/1353
# Downloaded image 1257/1353
# Downloaded image 1258/1353
# Downloaded image 1259/1353
# Downloaded image 1260/1353
# Downloaded image 1261/1353
# Downloaded image 1262/1353
# Downloaded image 1263/1353
# Downloaded image 1264/1353
# Downloaded image 1265/1353
# Downloaded image 1266/1353
# Downloaded image 1267/1353
# Downloaded image 1268/1353
# Downloaded image 1269/1353
# Downloaded image 1270/1353
# Downloaded image 1271/1353
# Downloaded image 1272/1353
# Downloaded image 1273/1353
# Downloaded image 1274/1353
# Downloaded image 1275/1353
# Downloaded image 1276/1353
# Downloaded image 1277/1353
# Downloaded image 1278/1353
# Downloaded image 1279/1353
# Downloaded image 1280/1353
# Downloaded image 1281/1353
# Downloaded image 1282/1353
# Downloaded image 1283/1353
# Downloaded image 1284/1353
# Downloaded image 1285/1353
# Downloaded image 1286/1353
# Downloaded image 1287/1353
# Downloaded image 1288/1353
# Downloaded image 1289/1353
# Downloaded image 1290/1353
# Downloaded image 1291/1353
# Downloaded image 1292/1353
# Downloaded image 1293/1353
# Downloaded image 1294/1353
# Downloaded image 1295/1353
# Downloaded image 1296/1353
# Downloaded image 1297/1353
# Downloaded image 1298/1353
# Downloaded image 1299/1353
# Downloaded image 1300/1353
# Downloaded image 1301/1353
# Downloaded image 1302/1353
# Downloaded image 1303/1353
# Downloaded image 1304/1353
# Downloaded image 1305/1353
# Downloaded image 1306/1353
# Downloaded image 1307/1353
# Downloaded image 1308/1353
# Downloaded image 1309/1353
# Downloaded image 1310/1353
# Downloaded image 1311/1353
# Downloaded image 1312/1353
# Downloaded image 1313/1353
# Downloaded image 1314/1353
# Downloaded image 1315/1353
# Downloaded image 1316/1353
# Downloaded image 1317/1353
# Downloaded image 1318/1353
# Downloaded image 1319/1353
# Downloaded image 1320/1353
# Downloaded image 1321/1353
# Downloaded image 1322/1353
# Downloaded image 1323/1353
# Downloaded image 1324/1353
# Downloaded image 1325/1353
# Downloaded image 1326/1353
# Downloaded image 1327/1353
# Downloaded image 1328/1353
# Downloaded image 1329/1353
# Downloaded image 1330/1353
# Downloaded image 1331/1353
# Downloaded image 1332/1353
# Downloaded image 1333/1353
# Downloaded image 1334/1353
# Downloaded image 1335/1353
# Downloaded image 1336/1353
# Downloaded image 1337/1353
# Downloaded image 1338/1353
# Downloaded image 1339/1353
# Downloaded image 1340/1353
# Downloaded image 1341/1353
# Downloaded image 1342/1353
# Downloaded image 1343/1353
# Downloaded image 1344/1353
# Downloaded image 1345/1353
# Downloaded image 1346/1353
# Downloaded image 1347/1353
# Downloaded image 1348/1353
# Downloaded image 1349/1353
# Downloaded image 1350/1353
# Downloaded image 1351/1353
# Downloaded image 1352/1353
# Downloaded image 1353/1353
# Saving GeoTIFF. Please wait...
# Image saved to satellite.tif

# %% [markdown]
# You can also use your own image. Uncomment and run the following cell to use your own image.

# %%
# image = '/path/to/your/own/image.tif'

# %% [markdown]
# Display the downloaded image on the map.

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# Map(bottom=797282.0, center=[39.61177171008156, -93.19041252136232], controls=(ZoomControl(options=['position'…

# %% [markdown]
# ## Initialize SAM class
#
# Specify the file path to the model checkpoint. If it is not specified, the model will to downloaded to the working directory.

# %%
sam = SamGeo(
    model_type="vit_h",
    sam_kwargs=None,
)

# %% [markdown]
# ## Automatic mask generation
#
# Segment the image and save the results to a GeoTIFF file. Set `unique=True` to assign a unique ID to each object.

# %%
sam.generate(image, output="masks.tif", foreground=True, unique=True)

# %%
sam.show_masks(cmap="binary_r")

# %% [markdown]
# Show the object annotations (objects with random color) on the map.

# %%
sam.show_anns(axis="off", alpha=1, output="annotations.tif")

# %% [markdown]
# Compare images with a slider.

# %%
leafmap.image_comparison(
    "satellite.tif",
    "annotations.tif",
    label1="Satellite Image",
    label2="Image Segmentation",
)

# %% [markdown]
# Add image to the map.

# %%
m.add_raster("annotations.tif", alpha=0.5, layer_name="Masks")
m

# %% [markdown]
# Convert the object annotations to vector format, such as GeoPackage, Shapefile, or GeoJSON.

# %%
sam.tiff_to_vector("masks.tif", "masks.gpkg")

# %% [markdown]
# ## Automatic mask generation options
#
# There are several tunable parameters in automatic mask generation that control how densely points are sampled and what the thresholds are for removing low quality or duplicate masks. Additionally, generation can be automatically run on crops of the image to get improved performance on smaller objects, and post-processing can remove stray pixels and holes. Here is an example configuration that samples more masks:

# %%
sam_kwargs = {
    "points_per_side": 32,
    "pred_iou_thresh": 0.86,
    "stability_score_thresh": 0.92,
    "crop_n_layers": 1,
    "crop_n_points_downscale_factor": 2,
    "min_mask_region_area": 100,
}

# %%
sam = SamGeo(
    model_type="vit_h",
    sam_kwargs=sam_kwargs,
)

# %%
sam.generate(image, output="masks2.tif", foreground=True)

# %%
sam.show_masks(cmap="binary_r")

# %%
sam.show_anns(axis="off", opacity=1, output="annotations2.tif")

# %% [markdown]
# Compare images with a slider.

# %%
leafmap.image_comparison(
    image,
    "annotations.tif",
    label1="Image",
    label2="Image Segmentation",
)

# %% [markdown]
# Overlay the annotations on the image and use the slider to change the opacity interactively.

# %%
overlay_images(image, "annotations2.tif", backend="TkAgg")

# %% [markdown]
# ![](https://i.imgur.com/I1IhDgz.gif)
